# %% [markdown]
# ## AQI of India on 29112025
# #### Data Cleaning on this dataset
# <p>Downloaded this dataset from Indian government website to do some data cleaning and visualizations.</p>

# %%
import pandas as pd

# %%
df = pd.read_csv("/kaggle/input/aqi-of-india-on-29112025/AQI of India on 29112025.csv")

# %%
df.shape
# Out:
# (3331, 11)

# %%
df.columns
# Out:
# Index(['country', 'state', 'city', 'station', 'last_update', 'latitude',
#        'longitude', 'pollutant_id', 'pollutant_min', 'pollutant_max',
#        'pollutant_avg'],
#       dtype='object')

# %%
df.dtypes
# Out:
# country           object
# state             object
# city              object
# station           object
# last_update       object
# latitude         float64
# longitude        float64
# pollutant_id      object
# pollutant_min    float64
# pollutant_max    float64
# pollutant_avg    float64
# dtype: object

# %%
df.tail()
# Out:
#      country        state      city  \
# 3326   India  West_Bengal   Kolkata
# 3327   India  West_Bengal   Kolkata
# 3328   India  West_Bengal   Kolkata
# 3329   India  West_Bengal   Kolkata
# 3330   India  West_Bengal  Siliguri
#
#                                            station          last_update  \
# 3326  Rabindra Bharati University, Kolkata - WBPCB  29-11-2025 23:00:00
# 3327  Rabindra Bharati University, Kolkata - WBPCB  29-11-2025 23:00:00
# 3328             Rabindra Sarobar, Kolkata - WBPCB  29-11-2025 23:00:00
# 3329                     Victoria, Kolkata - WBPCB  29-11-2025 23:00:00
# 3330            Ward-32 Bapupara, Siliguri - WBPCB  29-11-2025 23:00:00
#
#        latitude  longitude pollutant_id  pollutant_min  pollutant_max  \
# 3326  22.627847  88.380669        PM2.5           50.0          297.0
# 3327  22.627847  88.380669           CO           28.0          118.0
# 3328  22.511060  88.351420        PM2.5           57.0          125.0
# ...

# %%
df.last_update.value_counts()
# Out:
# last_update
# 29-11-2025 23:00:00    3331
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3331, 11)

# %%
len(df[df['state']=='Bihar'])
# Out:
# 231

# %%
df.city[df['state']=='Bihar'].value_counts()
# Out:
# city
# Patna           40
# Gaya            19
# Muzaffarpur     19
# Bhagalpur       14
# Araria           7
# Hajipur          7
# Sasaram          7
# Rajgir           7
# Samastipur       7
# Siwan            7
# Munger           7
# Saharsa          7
# Purnia           7
# Chhapra          7
# Arrah            7
# Buxar            7
# Motihari         7
# Manguraha        7
# Kishanganj       7
# Katihar          7
# Bettiah          7
# Begusarai        7
# Aurangabad       7
# Bihar Sharif     6
# Name: count, dtype: int64

# %%
# fetching details of Patna only
df[['pollutant_id','pollutant_min','pollutant_max',]][df['city']=='Patna']
# Out:
#      pollutant_id  pollutant_min  pollutant_max
# 58           PM10           64.0           86.0
# 59            SO2            9.0           13.0
# 60          OZONE            8.0           11.0
# 61          PM2.5           48.0          195.0
# 62          OZONE           22.0           31.0
# 67           PM10           60.0          114.0
# 68            SO2            6.0            8.0
# 69            NH3            5.0           15.0
# 70          OZONE            7.0           47.0
# 765         PM2.5           59.0           69.0
# 766           SO2            1.0           28.0
# 767         OZONE           25.0           55.0
# 770           SO2            7.0           10.0
# 771         PM2.5           37.0           94.0
# 772         PM2.5           83.0          185.0
# 1424          SO2            7.0           10.0
# 1425           CO           32.0           90.0
# 1426          NO2            1.0           17.0
# 1427          NO2            6.0           12.0
# ...

# %%
df.pollutant_id.unique()
# Out:
# array(['SO2', 'OZONE', 'NO2', 'CO', 'PM10', 'NH3', 'PM2.5'], dtype=object)

# %%
df.dtypes
# Out:
# country           object
# state             object
# city              object
# station           object
# last_update       object
# latitude         float64
# longitude        float64
# pollutant_id      object
# pollutant_min    float64
# pollutant_max    float64
# pollutant_avg    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3331 entries, 0 to 3330
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   country        3331 non-null   object
#  1   state          3331 non-null   object
#  2   city           3331 non-null   object
#  3   station        3331 non-null   object
#  4   last_update    3331 non-null   object
#  5   latitude       3331 non-null   float64
#  6   longitude      3331 non-null   float64
#  7   pollutant_id   3331 non-null   object
#  8   pollutant_min  3093 non-null   float64
#  9   pollutant_max  3093 non-null   float64
#  10  pollutant_avg  3093 non-null   float64
# dtypes: float64(5), object(6)
# memory usage: 286.4+ KB

# %%
df.isnull().sum()
# Out:
# country            0
# state              0
# city               0
# station            0
# last_update        0
# latitude           0
# longitude          0
# pollutant_id       0
# pollutant_min    238
# pollutant_max    238
# pollutant_avg    238
# dtype: int64

# %%
df['pollutant_min'].mean()
# Out:
# 30.895570643388297

# %%
df.pollutant_min.fillna(df['pollutant_min'].mean(),inplace=True)
# Out:
# /tmp/ipykernel_90/3938094399.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.pollutant_min.fillna(df['pollutant_min'].mean(),inplace=True)

# %%
df.pollutant_min.mean()
# Out:
# 30.895570643388293

# %%
df['pollutant_min'].isnull().sum()
# Out:
# 0

# %%
df['pollutant_max'].fillna(df.pollutant_max.mean(),inplace=True)
# Out:
# /tmp/ipykernel_90/3065971021.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['pollutant_max'].fillna(df.pollutant_max.mean(),inplace=True)

# %%
df['pollutant_max'].isna().sum()
# Out:
# 0

# %%
df['pollutant_avg'].mean()
# Out:
# 57.7950210151956

# %%
df['pollutant_avg'] = df['pollutant_avg'].fillna(df['pollutant_avg'].mean())

# %%
df['pollutant_avg'].mean()
# Out:
# 57.79502101519561

# %%
df.isna().sum()
# Out:
# country          0
# state            0
# city             0
# station          0
# last_update      0
# latitude         0
# longitude        0
# pollutant_id     0
# pollutant_min    0
# pollutant_max    0
# pollutant_avg    0
# dtype: int64

# %%
df.head()
# Out:
#   country           state        city                                station  \
# 0   India  Andhra_Pradesh    Tirupati        Vaikuntapuram, Tirupati - APPCB
# 1   India  Andhra_Pradesh    Tirupati        Vaikuntapuram, Tirupati - APPCB
# 2   India  Andhra_Pradesh  Vijayawada          HB Colony, Vijayawada - APPCB
# 3   India  Andhra_Pradesh  Vijayawada  Rajiv Gandhi Park, Vijayawada - APPCB
# 4   India  Andhra_Pradesh  Vijayawada  Rajiv Gandhi Park, Vijayawada - APPCB
#
#            last_update   latitude  longitude pollutant_id  pollutant_min  \
# 0  29-11-2025 23:00:00  13.615387  79.409230          SO2      30.895571
# 1  29-11-2025 23:00:00  13.615387  79.409230        OZONE      16.000000
# 2  29-11-2025 23:00:00  16.536107  80.594233          NO2      22.000000
# 3  29-11-2025 23:00:00  16.509717  80.612222          NO2      43.000000
# 4  29-11-2025 23:00:00  16.509717  80.612222           CO      36.000000
#
#    pollutant_max  pollutant_avg
# ...

# %%
df['city']=df['city'].str.title()

# %%
df.state = df.state.str.title()

# %%
df.isnull().sum()
# Out:
# country          0
# state            0
# city             0
# station          0
# last_update      0
# latitude         0
# longitude        0
# pollutant_id     0
# pollutant_min    0
# pollutant_max    0
# pollutant_avg    0
# dtype: int64

# %%
df.describe()
# Out:
#           latitude    longitude  pollutant_min  pollutant_max  pollutant_avg
# count  3331.000000  3331.000000    3331.000000    3331.000000    3331.000000
# mean     22.753618    78.645615      30.895571      93.780472      57.795021
# std       5.511725     4.853500      33.798357      97.727982      60.849285
# min       8.514909    70.909168       1.000000       1.000000       1.000000
# 25%      19.074813    75.578914       7.000000      20.000000      14.000000
# 50%      23.549395    77.315741      19.000000      69.000000      40.000000
# 75%      27.213494    80.594233      40.000000     121.000000      76.000000
# max      34.066206    94.636574     319.000000     500.000000     346.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3331 entries, 0 to 3330
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   country        3331 non-null   object
#  1   state          3331 non-null   object
#  2   city           3331 non-null   object
#  3   station        3331 non-null   object
#  4   last_update    3331 non-null   object
#  5   latitude       3331 non-null   float64
#  6   longitude      3331 non-null   float64
#  7   pollutant_id   3331 non-null   object
#  8   pollutant_min  3331 non-null   float64
#  9   pollutant_max  3331 non-null   float64
#  10  pollutant_avg  3331 non-null   float64
# dtypes: float64(5), object(6)
# memory usage: 286.4+ KB

# %%
df.last_update
# Out:
# 0       29-11-2025 23:00:00
# 1       29-11-2025 23:00:00
# 2       29-11-2025 23:00:00
# 3       29-11-2025 23:00:00
# 4       29-11-2025 23:00:00
#                ...
# 3326    29-11-2025 23:00:00
# 3327    29-11-2025 23:00:00
# 3328    29-11-2025 23:00:00
# 3329    29-11-2025 23:00:00
# 3330    29-11-2025 23:00:00
# Name: last_update, Length: 3331, dtype: object

# %%
df.last_update.dtype
# Out:
# dtype('O')

# %%
pd.to_datetime(df['last_update'], dayfirst=True)
# Out:
# 0      2025-11-29 23:00:00
# 1      2025-11-29 23:00:00
# 2      2025-11-29 23:00:00
# 3      2025-11-29 23:00:00
# 4      2025-11-29 23:00:00
#                ...
# 3326   2025-11-29 23:00:00
# 3327   2025-11-29 23:00:00
# 3328   2025-11-29 23:00:00
# 3329   2025-11-29 23:00:00
# 3330   2025-11-29 23:00:00
# Name: last_update, Length: 3331, dtype: datetime64[ns]

# %%
df.head()
# Out:
#   country           state        city                                station  \
# 0   India  Andhra_Pradesh    Tirupati        Vaikuntapuram, Tirupati - APPCB
# 1   India  Andhra_Pradesh    Tirupati        Vaikuntapuram, Tirupati - APPCB
# 2   India  Andhra_Pradesh  Vijayawada          HB Colony, Vijayawada - APPCB
# 3   India  Andhra_Pradesh  Vijayawada  Rajiv Gandhi Park, Vijayawada - APPCB
# 4   India  Andhra_Pradesh  Vijayawada  Rajiv Gandhi Park, Vijayawada - APPCB
#
#            last_update   latitude  longitude pollutant_id  pollutant_min  \
# 0  29-11-2025 23:00:00  13.615387  79.409230          SO2      30.895571
# 1  29-11-2025 23:00:00  13.615387  79.409230        OZONE      16.000000
# 2  29-11-2025 23:00:00  16.536107  80.594233          NO2      22.000000
# 3  29-11-2025 23:00:00  16.509717  80.612222          NO2      43.000000
# 4  29-11-2025 23:00:00  16.509717  80.612222           CO      36.000000
#
#    pollutant_max  pollutant_avg
# ...

# %%
df['last_update'] = pd.to_datetime(df['last_update'], dayfirst=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3331 entries, 0 to 3330
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   country        3331 non-null   object
#  1   state          3331 non-null   object
#  2   city           3331 non-null   object
#  3   station        3331 non-null   object
#  4   last_update    3331 non-null   datetime64[ns]
#  5   latitude       3331 non-null   float64
#  6   longitude      3331 non-null   float64
#  7   pollutant_id   3331 non-null   object
#  8   pollutant_min  3331 non-null   float64
#  9   pollutant_max  3331 non-null   float64
#  10  pollutant_avg  3331 non-null   float64
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 286.4+ KB

# %%
df.head()
# Out:
#   country           state        city                                station  \
# 0   India  Andhra_Pradesh    Tirupati        Vaikuntapuram, Tirupati - APPCB
# 1   India  Andhra_Pradesh    Tirupati        Vaikuntapuram, Tirupati - APPCB
# 2   India  Andhra_Pradesh  Vijayawada          HB Colony, Vijayawada - APPCB
# 3   India  Andhra_Pradesh  Vijayawada  Rajiv Gandhi Park, Vijayawada - APPCB
# 4   India  Andhra_Pradesh  Vijayawada  Rajiv Gandhi Park, Vijayawada - APPCB
#
#           last_update   latitude  longitude pollutant_id  pollutant_min  \
# 0 2025-11-29 23:00:00  13.615387  79.409230          SO2      30.895571
# 1 2025-11-29 23:00:00  13.615387  79.409230        OZONE      16.000000
# 2 2025-11-29 23:00:00  16.536107  80.594233          NO2      22.000000
# 3 2025-11-29 23:00:00  16.509717  80.612222          NO2      43.000000
# 4 2025-11-29 23:00:00  16.509717  80.612222           CO      36.000000
#
#    pollutant_max  pollutant_avg
# 0      93.780472      57.795021
# ...

# %%
# opened in collab and pushing in github

# %%
# succesfully pulled from github after making changes from collab
